# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from matplotlib import animation, rc
from IPython.display import HTML
import matplotlib.cm as cm
import matplotlib.patches as mpatches
from sklearn import linear_model
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import statsmodels.stats.proportion as ssp
plt.style.use('rossidata')
# Out:
# /Users/nicholasrossi/anaconda/lib/python3.5/site-packages/sklearn/utils/fixes.py:313: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   _nan_object_mask = _nan_object_array != _nan_object_array

# %%
plt.subplots()
fig,ax=plt.subplots(2,1,figsize=(4,8))
def information_calculator(px):
    vals=1-(-px*np.log2(px)-(1-px)*np.log2(1-px))
    vals[np.isnan(vals)]=1
    return vals
def entropy_calculator(px):
    vals=(-px*np.log2(px)-(1-px)*np.log2(1-px))
    vals[np.isnan(vals)]=0
    return vals

#number of fluorophore splits
n_splits=10
column_num=61

grid=np.zeros((n_splits,column_num-1))

vals=np.linspace(0,1.0,column_num-1)

for x in range(n_splits):
    grid[x,:]=np.linspace(0,1,column_num-1)/((x+1)*0.15)

sns.heatmap(np.flipud(grid)*100,ax=ax[0],cmap="rainbow",vmin=0, vmax=100,cbar_kws={'label': '% chance of death'})

information_time=np
information_time=np.nanmean(information_calculator(grid),0)-information_calculator(np.mean(grid,0))
ax[1].plot(information_time)
fig

# %%
np.nanmean(information_calculator(grid),0)-information_calculator(np.mean(grid,0))
# Out:
# array([ 0.        ,  0.01541545,  0.03233476,  0.05105375,  0.07197533,
#         0.09567714,  0.12305204,  0.15565909,  0.1969596 ,  0.25292423,
#         0.26086954,  0.26665302,  0.27049421,  0.27263476,  0.27337968,
#         0.27317851,  0.2728314 ,  0.27427516,  0.27420123,  0.24605049,
#         0.21367548,  0.1768599 ,  0.13533349,  0.08876735,  0.03678268,
#        -0.02097229, -0.08429081, -0.16232122, -0.27014768, -0.40035316,
#        -0.57614902, -0.62892471, -0.61853271, -0.6057735 , -0.59009399,
#        -0.56999016, -0.55493839, -0.54765658, -0.53915435, -0.52935018,
#        -0.51813173, -0.50533503, -0.49069686, -0.47371364, -0.45285881,
#        -0.43966187, -0.43062028, -0.42064543, -0.40966292, -0.39757094,
#        -0.38422085, -0.3693714 , -0.35254517, -0.33202557, -0.32146094,
#        -0.312195  , -0.30219962, -0.29140698, -0.27972409, -0.26701402])

# %%
information_calculator(np.mean(grid,0))
# Out:
# array([  1.00000000e+00,   7.90313451e-01,   6.48452901e-01,
#          5.33268457e-01,   4.36063150e-01,   3.52743920e-01,
#          2.80932850e-01,   2.19089188e-01,   1.66147246e-01,
#          1.21339315e-01,   8.40989888e-02,   5.40042241e-02,
#          3.07420423e-02,   1.40859521e-02,   3.88140056e-03,
#          3.66652667e-05,   2.51775308e-03,   1.13465656e-02,
#          2.66020775e-02,   4.84246908e-02,   7.70243865e-02,
#          1.12693932e-01,   1.55829427e-01,   2.06962300e-01,
#          2.66810487e-01,   3.36364220e-01,   4.17040247e-01,
#          5.10988601e-01,   6.21804302e-01,   7.56676723e-01,
#          9.38904257e-01,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00,
#          1.00000000e+00,   1.00000000e+00,   1.00000000e+00])
